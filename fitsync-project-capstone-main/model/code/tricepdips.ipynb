# %%
import csv
import cv2
import numpy as np
import pandas as pd
import os
import sys
import tempfile
import tqdm
import itertools
from matplotlib import pyplot as plt
from math import atan2, degrees, sqrt
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path of the folder that contains the entire dataset
dataset_path = '/content/drive/MyDrive/capstone/tricep dips/dataset'

# Path of the folder to store the split dataset
train_dir = '/content/drive/MyDrive/capstone/tricep dips/dataset/train'
val_dir = '/content/drive/MyDrive/capstone/tricep dips/dataset/val'
test_dir = '/content/drive/MyDrive/capstone/tricep dips/dataset/test'

# Path for each class tricep dips position
up_position_path = dataset_path + '/tricep_dips_up'
down_position_path = dataset_path + '/tricep_dips_down'

# %%
def split_dataset(position_path, train_dir, val_dir, test_dir):
  # Split the dataset into train and test subsets
  train_images, test_images = train_test_split(os.listdir(position_path), test_size=0.2)

  # Split the remaining train subset into train and val subsets
  train_images, val_images = train_test_split(train_images, test_size=0.25)

  # Move the images to the train, validation, and test folders
  def move_images(path_dir, images):
      for image in images:
          os.rename(os.path.join(position_path, image), os.path.join(path_dir, image))

  move_images(train_dir, train_images)
  move_images(val_dir, val_images)
  move_images(test_dir, test_images)

# Run the split_dataset function to split the dataset of each push up position.
split_dataset(up_position_path, train_dir+'/up', val_dir+'/up', test_dir+'/up')
split_dataset(down_position_path, train_dir+'/down', val_dir+'/down', test_dir+'/down')

# %%
# Download model from TF Hub and check out inference code from GitHub
# !wget -q -O movenet_thunder.tflite https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/tflite/float16/4?lite-format=tflite
# !git clone https://github.com/tensorflow/examples.git
pose_sample_rpi_path = os.path.join(os.getcwd(), 'examples/lite/examples/pose_estimation/raspberry_pi')
sys.path.append(pose_sample_rpi_path)

# Load MoveNet Thunder model
import utils
from data import BodyPart
from ml import Movenet
movenet = Movenet('movenet_thunder')

# Define function to run pose estimation using MoveNet Thunder.
# Apply MoveNet's cropping algorithm and run inference multiple times on the input image to improve pose estimation accuracy.
def detect(input_tensor, inference_count=3):
  image_height, image_width, channel = input_tensor.shape

  # Detect pose using the full input image
  movenet.detect(input_tensor.numpy(), reset_crop_region=True)

  # Repeatedly using previous detection result to identify the region of interest and only croping that region to improve detection accuracy
  for _ in range(inference_count - 1):
    person = movenet.detect(input_tensor.numpy(),
                            reset_crop_region=False)

  return person
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 23745, done.
# remote: Total 23745 (delta 0), reused 0 (delta 0), pack-reused 23745
# Receiving objects: 100% (23745/23745), 44.08 MiB | 27.95 MiB/s, done.
# Resolving deltas: 100% (12942/12942), done.

# %%
def draw_prediction_on_image(image, person, crop_region=None, close_figure=True, keep_input_size=False):
  # Draw the detection result on top of the image.
  image_np = utils.visualize(image, [person])

  # Plot the image with detection results.
  height, width, channel = image.shape
  aspect_ratio = float(width) / height
  fig, ax = plt.subplots(figsize=(12 * aspect_ratio, 12))
  im = ax.imshow(image_np)

  if close_figure:
    plt.close(fig)

  if not keep_input_size:
    image_np = utils.keep_aspect_ratio_resizer(image_np, (512, 512))

  return image_np

# %%
class MoveNetPreprocessor(object):
  def __init__(self,
               images_in_folder,
               images_out_folder,
               csvs_out_path):
    self._images_in_folder = images_in_folder
    self._images_out_folder = images_out_folder
    self._csvs_out_path = csvs_out_path
    self._messages = []

    # Create a temp dir to store the pose CSVs per class
    self._csvs_out_folder_per_class = tempfile.mkdtemp()

    # Get list of pose classes and print image statistics
    self._pose_class_names = sorted(
        [n for n in os.listdir(self._images_in_folder) if not n.startswith('.')]
        )

  def process(self, per_pose_class_limit=None, detection_threshold=0.1):
    # Loop through the classes and preprocess its images
    for pose_class_name in self._pose_class_names:
      print('Preprocessing', pose_class_name, file=sys.stderr)

      # Paths for the pose class.
      images_in_folder = os.path.join(self._images_in_folder, pose_class_name)
      images_out_folder = os.path.join(self._images_out_folder, pose_class_name)
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  pose_class_name + '.csv')
      if not os.path.exists(images_out_folder):
        os.makedirs(images_out_folder)

      # Detect landmarks in each image and write it to a CSV file
      with open(csv_out_path, 'w') as csv_out_file:
        csv_out_writer = csv.writer(csv_out_file,
                                    delimiter=',',
                                    quoting=csv.QUOTE_MINIMAL)
        # Get list of images
        image_names = sorted(
            [n for n in os.listdir(images_in_folder) if not n.startswith('.')])
        if per_pose_class_limit is not None:
          image_names = image_names[:per_pose_class_limit]

        valid_image_count = 0

        # Detect pose landmarks from each image
        for image_name in tqdm.tqdm(image_names):
          image_path = os.path.join(images_in_folder, image_name)

          try:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image)
          except:
            self._messages.append('Skipped ' + image_path + '. Invalid image.')
            continue
          else:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image)
            image_height, image_width, channel = image.shape

          # Skip images that isn't RGB because Movenet requires RGB images
          if channel != 3:
            self._messages.append('Skipped ' + image_path +
                                  '. Image isn\'t in RGB format.')
            continue
          person = detect(image)

          # Save landmarks if all landmarks were detected
          min_landmark_score = min(
              [keypoint.score for keypoint in person.keypoints])
          should_keep_image = min_landmark_score >= detection_threshold
          if not should_keep_image:
            self._messages.append('Skipped ' + image_path +
                                  '. No pose was confidentlly detected.')
            continue

          valid_image_count += 1

          # Draw the prediction result on top of the image for debugging later
          output_overlay = draw_prediction_on_image(
              image.numpy().astype(np.uint8), person,
              close_figure=True, keep_input_size=True)

          # Write detection result into an image file
          output_frame = cv2.cvtColor(output_overlay, cv2.COLOR_RGB2BGR)
          cv2.imwrite(os.path.join(images_out_folder, image_name), output_frame)

          # Get landmarks and scale it to the same size as the input image
          pose_landmarks = np.array(
              [[keypoint.coordinate.x, keypoint.coordinate.y, keypoint.score]
                for keypoint in person.keypoints],
              dtype=np.float32)

          # Write the landmark coordinates to its per-class CSV file
          coordinates = pose_landmarks.flatten().astype(str).tolist()
          csv_out_writer.writerow([image_name] + coordinates)

        if not valid_image_count:
          raise RuntimeError(
              'No valid images found for the "{}" class.'
              .format(pose_class_name))

    # Print the error message collected during preprocessing.
    print('\n'.join(self._messages))

    # Combine all per-class CSVs into a single output file
    all_landmarks_df = self._all_landmarks_as_dataframe()
    all_landmarks_df.to_csv(self._csvs_out_path, index=False)

  def class_names(self):
    """List of classes found in the training dataset."""
    return self._pose_class_names

  def _all_landmarks_as_dataframe(self):
    """Merge all per-class CSVs into a single dataframe."""
    total_df = None
    for class_index, class_name in enumerate(self._pose_class_names):
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  class_name + '.csv')
      per_class_df = pd.read_csv(csv_out_path, header=None)

      # Add the labels
      per_class_df['class_no'] = [class_index]*len(per_class_df)
      per_class_df['class_name'] = [class_name]*len(per_class_df)

      # Append the folder name to the filename column (first column)
      per_class_df[per_class_df.columns[0]] = (os.path.join(class_name, '')
        + per_class_df[per_class_df.columns[0]].astype(str))

      if total_df is None:
        # For the first class, assign its data to the total dataframe
        total_df = per_class_df
      else:
        # Concatenate each class's data into the total dataframe
        total_df = pd.concat([total_df, per_class_df], axis=0)

    list_name = [[bodypart.name + '_x', bodypart.name + '_y',
                  bodypart.name + '_score'] for bodypart in BodyPart]
    header_name = []
    for columns_name in list_name:
      header_name += columns_name
    header_name = ['file_name'] + header_name
    header_map = {total_df.columns[i]: header_name[i]
                  for i in range(len(header_name))}

    total_df.rename(header_map, axis=1, inplace=True)

    return total_df

# %%
def preprocess_data(path_dir, out_dir):
    images_in_folder = path_dir
    images_out_folder = out_dir
    csvs_out_path = path_dir+'/_landmark.csv'

    preprocessor = MoveNetPreprocessor(
        images_in_folder=images_in_folder,
        images_out_folder=images_out_folder,
        csvs_out_path=csvs_out_path,)
    preprocessor.process()

preprocess_data(train_dir, dataset_path+'/output_train')
preprocess_data(val_dir, dataset_path+'/output_val')
preprocess_data(test_dir, dataset_path+'/output_test')
# Out:
# Preprocessing down
# 100%|██████████| 213/213 [11:57<00:00,  3.37s/it]
# Preprocessing up
# 100%|██████████| 207/207 [11:38<00:00,  3.37s/it]
# Preprocessing down
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1000041.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1000131.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1000141.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1000151.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1000211.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1000221.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1000231.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1000301.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1000311.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1000331.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1000391.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1000401.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1000411.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_100301.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_100421.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1100031.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1100091.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1100101.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1100111.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1100171.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1100181.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1100241.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1100251.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1100261.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1100331.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1100341.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1400001.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1400011.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1400051.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1400061.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1600011.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1600021.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1600031.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1600071.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1600091.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1600121.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1600141.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1600151.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1600191.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1600201.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1600211.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1600251.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1600271.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1600311.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1700321.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1700441.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1800241.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1800541.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1900421.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_1900441.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_2000001.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_2000031.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_2000041.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_2000081.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_2000091.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_2000131.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_2000141.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_2000171.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_2000181.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_2000231.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_2000271.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_200261.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_200321.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_200371.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_200441.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_200631.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_200641.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_200701.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_300221.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_300341.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_300351.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_400031.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_400041.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_400171.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_400181.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_700031.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_700041.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_700101.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_700111.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_700131.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_700191.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_700211.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_700281.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_800041.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_800061.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_800071.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_800131.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_800141.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_800151.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_800161.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_900031.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_900041.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_900051.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_900121.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_900131.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_900201.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_900211.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_900221.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_900231.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_900291.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_900311.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_g13.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_g5.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/down/tricep dips_g7.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1000001.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1000011.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1000071.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1000081.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1000091.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1000101.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1000161.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1000181.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1000191.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1000261.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1000351.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1000361.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1000371.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1000431.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100061.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100071.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100081.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100091.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100131.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100151.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100211.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100271.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100311.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100331.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100371.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100381.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100431.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100441.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100451.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100491.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100511.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_100561.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1100291.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1100301.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1400071.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1600041.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1600111.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1600161.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1600171.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1600221.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_1900471.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_200241.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_200521.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_200531.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_200541.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_200581.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_300191.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_300201.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_300241.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_300251.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_300261.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_300301.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_300311.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_300321.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_400001.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_400011.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_400091.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_400101.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_400111.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_400151.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_400161.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_700061.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_700071.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_700081.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_700241.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_700251.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_800001.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_800011.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_800081.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_800091.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_800101.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_800171.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_900001.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_900011.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_900101.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_900191.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_900261.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/train/up/tricep dips_900281.jpg. No pose was confidentlly detected.
# 100%|██████████| 82/82 [05:05<00:00,  3.73s/it]
# Preprocessing up
# 100%|██████████| 80/80 [04:53<00:00,  3.67s/it]
# Preprocessing down
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1000031.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1000051.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1000321.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1000391.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1100031.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1100111.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1100321.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1100341.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1400001.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1400091.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1400101.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1600001.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1600071.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1600081.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1600131.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1600151.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1600261.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_1900431.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_2000041.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_2000131.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_2000231.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_2000271.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_200261.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_200441.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_200701.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_300211.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_300351.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_400131.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_400171.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_700121.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_700131.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_700281.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_700301.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_800051.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_900131.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/down/tricep dips_g12.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_1000101.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_1000161.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_1000171.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_1000181.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_1000251.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_1000271.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_1000281.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_100151.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_100311.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_100391.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_100501.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_100561.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_1600161.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_200531.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_300201.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_300251.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_300301.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_300311.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_300321.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_300331.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_300371.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_400011.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_400071.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_400081.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_400091.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_700001.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_700061.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_700081.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_700161.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_700251.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_800081.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_800171.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_900101.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/val/up/tricep dips_900281.jpg. No pose was confidentlly detected.
# 100%|██████████| 50/50 [03:04<00:00,  3.70s/it]
# Preprocessing up
# 100%|██████████| 46/46 [02:49<00:00,  3.68s/it]
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_1000031.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_1000051.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_1000321.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_1000411.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_100421.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_1100101.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_1100181.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_1100251.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_1400101.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_1600021.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_1600081.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_1800541.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_2000091.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_2000171.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_2000221.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_200321.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_400031.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_700041.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_700121.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_700211.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_800141.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_900031.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_900141.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_900201.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_900301.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_900311.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_g19.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/down/tricep dips_g7.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_1000251.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_100081.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_100091.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_100201.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_100271.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_100441.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_100451.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_100501.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_100511.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_1600221.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_1900471.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_200521.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_400111.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_400151.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_400161.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_700001.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_800001.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_900191.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/tricep dips/dataset/test/up/tricep dips_900261.jpg. No pose was confidentlly detected.

# %%
# Path file _landmark.csv tiap dataset
TRAINING_FILE = '/content/drive/MyDrive/capstone/tricep dips/dataset/train/_landmark.csv'
VALIDATION_FILE = '/content/drive/MyDrive/capstone/tricep dips/dataset/val/_landmark.csv'
TESTING_FILE = '/content/drive/MyDrive/capstone/tricep dips/dataset/test/_landmark.csv'

# %%
# Fungsi untuk memuat data dari file CSV dan mengabaikan kolom pertama dan terakhir
def load_data(file_path):
    dataframe = pd.read_csv(file_path)
    df_to_process = dataframe.copy()

    # Drop the file_name columns as you don't need it during training.
    df_to_process.drop(columns=['file_name'], inplace=True)

    # Extract the list of class names
    classes = df_to_process.pop('class_name').unique()

    # Extract the labels
    y = df_to_process.pop('class_no')

    # Convert the input features and labels into the correct format for training.
    X = df_to_process.astype('float64').values

    return X, y, classes, dataframe

# Load train, validation, and test data
try:
    X_train, y_train, class_names, _ = load_data(TRAINING_FILE)
    X_val, y_val, class_names, _ = load_data(VALIDATION_FILE)
    X_test, y_test, class_names, _ = load_data(TESTING_FILE)
except Exception as e:
    print(f"Error loading data: {e}")

print(f"Length X_train: {len(X_train)}, X_train Shape: {X_train.shape}, Length y_train: {len(y_train)}, y_train Shape: {y_train.shape}")
print(f"Length X_val: {len(X_val)}, X_val Shape: {X_val.shape}, Length y_val: {len(y_val)}, y_val Shape: {y_val.shape}")
print(f"Length X_test: {len(X_test)}, X_test Shape: {X_test.shape}, Length y_test: {len(y_test)}, y_test Shape: {y_test.shape}")
# Out:
# Length X_train: 238, X_train Shape: (238, 51), Length y_train: 238, y_train Shape: (238,)
# Length X_val: 92, X_val Shape: (92, 51), Length y_val: 92, y_val Shape: (92,)
# Length X_test: 49, X_test Shape: (49, 51), Length y_test: 49, y_test Shape: (49,)

# %%
def get_center_point(landmarks, left_bodypart, right_bodypart):
  """Calculates the center point of the two given landmarks."""

  left = tf.gather(landmarks, left_bodypart.value, axis=1)
  right = tf.gather(landmarks, right_bodypart.value, axis=1)
  center = left * 0.5 + right * 0.5
  return center


def get_pose_size(landmarks, torso_size_multiplier=2.5):
  """Calculates pose size.

  It is the maximum of two values:
    * Torso size multiplied by `torso_size_multiplier`
    * Maximum distance from pose center to any pose landmark
  """
  # Hips center
  hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                 BodyPart.RIGHT_HIP)

  # Shoulders center
  shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER,
                                      BodyPart.RIGHT_SHOULDER)

  # Torso size as the minimum body size
  torso_size = tf.linalg.norm(shoulders_center - hips_center)

  # Pose center
  pose_center_new = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                     BodyPart.RIGHT_HIP)
  pose_center_new = tf.expand_dims(pose_center_new, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to perform substraction
  pose_center_new = tf.broadcast_to(pose_center_new,
                                    [tf.size(landmarks) // (17*2), 17, 2])

  # Dist to pose center
  d = tf.gather(landmarks - pose_center_new, 0, axis=0,
                name="dist_to_pose_center")
  # Max dist to pose center
  max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

  # Normalize scale
  pose_size = tf.maximum(torso_size * torso_size_multiplier, max_dist)

  return pose_size


def normalize_pose_landmarks(landmarks):
  """Normalizes the landmarks translation by moving the pose center to (0,0) and
  scaling it to a constant pose size.
  """
  # Move landmarks so that the pose center becomes (0,0)
  pose_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                 BodyPart.RIGHT_HIP)
  pose_center = tf.expand_dims(pose_center, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to perform
  # substraction
  pose_center = tf.broadcast_to(pose_center,
                                [tf.size(landmarks) // (17*2), 17, 2])
  landmarks = landmarks - pose_center

  # Scale the landmarks to a constant pose size
  pose_size = get_pose_size(landmarks)
  landmarks /= pose_size

  return landmarks


def landmarks_to_embedding(landmarks_and_scores):
  """Converts the input landmarks into a pose embedding."""
  # Reshape the flat input into a matrix with shape=(17, 3)
  reshaped_inputs = keras.layers.Reshape((17, 3))(landmarks_and_scores)

  # Normalize landmarks 2D
  landmarks = normalize_pose_landmarks(reshaped_inputs[:, :, :2])

  # Flatten the normalized landmark coordinates into a vector
  embedding = keras.layers.Flatten()(landmarks)

  return embedding

# %%
# Define the model

model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(51,)),
    tf.keras.layers.Lambda(landmarks_to_embedding),
    tf.keras.layers.Dense(128, activation=tf.nn.relu6),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation=tf.nn.relu6),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation="sigmoid")
])
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda_6 (Lambda)           (None, 34)                0
#
#  dense_20 (Dense)            (None, 128)               4480
#
#  dropout_14 (Dropout)        (None, 128)               0
#
#  dense_21 (Dense)            (None, 64)                8256
#
#  dropout_15 (Dropout)        (None, 64)                0
#
#  dense_22 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 12801 (50.00 KB)
# Trainable params: 12801 (50.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Add a checkpoint callback to store the checkpoint that has the highest validation accuracy.
checkpoint_path = "weights.best.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True,
                             mode='max')
earlystopping = keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                              patience=20)

# Start training
history = model.fit(X_train, y_train,
                    epochs=200,
                    batch_size=8,
                    validation_data=(X_val, y_val),
                    callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/200
# 16/30 [===============>..............] - ETA: 0s - loss: 0.6899 - accuracy: 0.5234
# Epoch 1: val_accuracy improved from -inf to 0.51087, saving model to weights.best.hdf5
# 30/30 [==============================] - 2s 14ms/step - loss: 0.6823 - accuracy: 0.5378 - val_loss: 0.6748 - val_accuracy: 0.5109
# Epoch 2/200
# 20/30 [===================>..........] - ETA: 0s - loss: 0.6717 - accuracy: 0.5688
# Epoch 2: val_accuracy improved from 0.51087 to 0.57609, saving model to weights.best.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.6600 - accuracy: 0.6092 - val_loss: 0.6592 - val_accuracy: 0.5761
# Epoch 3/200
#  1/30 [>.............................] - ETA: 0s - loss: 0.6584 - accuracy: 0.7500
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 21/30 [====================>.........] - ETA: 0s - loss: 0.6345 - accuracy: 0.6250
# Epoch 3: val_accuracy improved from 0.57609 to 0.63043, saving model to weights.best.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.6412 - accuracy: 0.6008 - val_loss: 0.6326 - val_accuracy: 0.6304
# Epoch 4/200
# 23/30 [======================>.......] - ETA: 0s - loss: 0.6157 - accuracy: 0.7446
# Epoch 4: val_accuracy improved from 0.63043 to 0.80435, saving model to weights.best.hdf5
# 30/30 [==============================] - 0s 7ms/step - loss: 0.6132 - accuracy: 0.7395 - val_loss: 0.5864 - val_accuracy: 0.8043
# Epoch 5/200
# 18/30 [=================>............] - ETA: 0s - loss: 0.5710 - accuracy: 0.7639
# Epoch 5: val_accuracy improved from 0.80435 to 0.86957, saving model to weights.best.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.5620 - accuracy: 0.7731 - val_loss: 0.5304 - val_accuracy: 0.8696
# Epoch 6/200
# 19/30 [==================>...........] - ETA: 0s - loss: 0.5165 - accuracy: 0.8355
# Epoch 6: val_accuracy did not improve from 0.86957
# 30/30 [==============================] - 0s 4ms/step - loss: 0.5117 - accuracy: 0.8025 - val_loss: 0.4763 - val_accuracy: 0.8261
# Epoch 7/200
# 24/30 [=======================>......] - ETA: 0s - loss: 0.4651 - accuracy: 0.8229
# Epoch 7: val_accuracy improved from 0.86957 to 0.88043, saving model to weights.best.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.4519 - accuracy: 0.8319 - val_loss: 0.4075 - val_accuracy: 0.8804
# Epoch 8/200
# 21/30 [====================>.........] - ETA: 0s - loss: 0.4217 - accuracy: 0.8512
# Epoch 8: val_accuracy did not improve from 0.88043
# 30/30 [==============================] - 0s 5ms/step - loss: 0.4076 - accuracy: 0.8529 - val_loss: 0.3703 - val_accuracy: 0.8696
# Epoch 9/200
# 22/30 [=====================>........] - ETA: 0s - loss: 0.3181 - accuracy: 0.9318
# Epoch 9: val_accuracy improved from 0.88043 to 0.91304, saving model to weights.best.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3249 - accuracy: 0.9244 - val_loss: 0.3157 - val_accuracy: 0.9130
# Epoch 10/200
# 24/30 [=======================>......] - ETA: 0s - loss: 0.3100 - accuracy: 0.8958
# Epoch 10: val_accuracy did not improve from 0.91304
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2958 - accuracy: 0.9076 - val_loss: 0.3017 - val_accuracy: 0.9022
# Epoch 11/200
# 16/30 [===============>..............] - ETA: 0s - loss: 0.2693 - accuracy: 0.9141
# Epoch 11: val_accuracy improved from 0.91304 to 0.92391, saving model to weights.best.hdf5
# 30/30 [==============================] - 0s 6ms/step - loss: 0.2772 - accuracy: 0.9076 - val_loss: 0.2642 - val_accuracy: 0.9239
# Epoch 12/200
# 17/30 [================>.............] - ETA: 0s - loss: 0.2209 - accuracy: 0.9412
# Epoch 12: val_accuracy did not improve from 0.92391
# 30/30 [==============================] - 0s 5ms/step - loss: 0.2428 - accuracy: 0.9286 - val_loss: 0.2738 - val_accuracy: 0.9022
# Epoch 13/200
# 25/30 [========================>.....] - ETA: 0s - loss: 0.2384 - accuracy: 0.9150
# Epoch 13: val_accuracy improved from 0.92391 to 0.93478, saving model to weights.best.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.2421 - accuracy: 0.9202 - val_loss: 0.2368 - val_accuracy: 0.9348
# Epoch 14/200
# 21/30 [====================>.........] - ETA: 0s - loss: 0.2437 - accuracy: 0.9226
# Epoch 14: val_accuracy did not improve from 0.93478
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2289 - accuracy: 0.9286 - val_loss: 0.2567 - val_accuracy: 0.9130
# Epoch 15/200
# 20/30 [===================>..........] - ETA: 0s - loss: 0.1843 - accuracy: 0.9688
# Epoch 15: val_accuracy did not improve from 0.93478
# 30/30 [==============================] - 0s 5ms/step - loss: 0.2186 - accuracy: 0.9286 - val_loss: 0.2399 - val_accuracy: 0.9130
# Epoch 16/200
# 23/30 [======================>.......] - ETA: 0s - loss: 0.2146 - accuracy: 0.9185
# Epoch 16: val_accuracy did not improve from 0.93478
# 30/30 [==============================] - 0s 4ms/step - loss: 0.2059 - accuracy: 0.9244 - val_loss: 0.1931 - val_accuracy: 0.9348
# Epoch 17/200
# 24/30 [=======================>......] - ETA: 0s - loss: 0.1512 - accuracy: 0.9427
# Epoch 17: val_accuracy improved from 0.93478 to 0.94565, saving model to weights.best.hdf5
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1793 - accuracy: 0.9328 - val_loss: 0.1906 - val_accuracy: 0.9457
# Epoch 18/200
# 17/30 [================>.............] - ETA: 0s - loss: 0.1915 - accuracy: 0.9118
# Epoch 18: val_accuracy did not improve from 0.94565
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1924 - accuracy: 0.9286 - val_loss: 0.1910 - val_accuracy: 0.9348
# Epoch 19/200
# 22/30 [=====================>........] - ETA: 0s - loss: 0.1734 - accuracy: 0.9205
# Epoch 19: val_accuracy improved from 0.94565 to 0.95652, saving model to weights.best.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1672 - accuracy: 0.9244 - val_loss: 0.1625 - val_accuracy: 0.9565
# Epoch 20/200
# 24/30 [=======================>......] - ETA: 0s - loss: 0.1657 - accuracy: 0.9427
# Epoch 20: val_accuracy did not improve from 0.95652
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1541 - accuracy: 0.9454 - val_loss: 0.1544 - val_accuracy: 0.9565
# Epoch 21/200
# 18/30 [=================>............] - ETA: 0s - loss: 0.2148 - accuracy: 0.9306
# Epoch 21: val_accuracy did not improve from 0.95652
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1877 - accuracy: 0.9454 - val_loss: 0.1547 - val_accuracy: 0.9565
# Epoch 22/200
# 19/30 [==================>...........] - ETA: 0s - loss: 0.1827 - accuracy: 0.9276
# Epoch 22: val_accuracy did not improve from 0.95652
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1673 - accuracy: 0.9370 - val_loss: 0.1876 - val_accuracy: 0.9348
# Epoch 23/200
# 21/30 [====================>.........] - ETA: 0s - loss: 0.1855 - accuracy: 0.9345
# Epoch 23: val_accuracy did not improve from 0.95652
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1747 - accuracy: 0.9370 - val_loss: 0.1479 - val_accuracy: 0.9565
# Epoch 24/200
# 29/30 [============================>.] - ETA: 0s - loss: 0.1344 - accuracy: 0.9440
# Epoch 24: val_accuracy did not improve from 0.95652
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1350 - accuracy: 0.9412 - val_loss: 0.1361 - val_accuracy: 0.9565
# Epoch 25/200
# 17/30 [================>.............] - ETA: 0s - loss: 0.1660 - accuracy: 0.9191
# Epoch 25: val_accuracy did not improve from 0.95652
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1422 - accuracy: 0.9412 - val_loss: 0.1324 - val_accuracy: 0.9457
# Epoch 26/200
# 18/30 [=================>............] - ETA: 0s - loss: 0.1197 - accuracy: 0.9583
# Epoch 26: val_accuracy did not improve from 0.95652
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1385 - accuracy: 0.9454 - val_loss: 0.1549 - val_accuracy: 0.9457
# Epoch 27/200
# 20/30 [===================>..........] - ETA: 0s - loss: 0.0991 - accuracy: 0.9688
# Epoch 27: val_accuracy did not improve from 0.95652
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1073 - accuracy: 0.9580 - val_loss: 0.1309 - val_accuracy: 0.9457
# Epoch 28/200
# 16/30 [===============>..............] - ETA: 0s - loss: 0.0977 - accuracy: 0.9531
# Epoch 28: val_accuracy did not improve from 0.95652
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1250 - accuracy: 0.9412 - val_loss: 0.1233 - val_accuracy: 0.9457
# Epoch 29/200
# 20/30 [===================>..........] - ETA: 0s - loss: 0.1138 - accuracy: 0.9625
# Epoch 29: val_accuracy did not improve from 0.95652
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1128 - accuracy: 0.9580 - val_loss: 0.1333 - val_accuracy: 0.9565
# Epoch 30/200
# 30/30 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9496
# Epoch 30: val_accuracy did not improve from 0.95652
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1157 - accuracy: 0.9496 - val_loss: 0.1434 - val_accuracy: 0.9457
# Epoch 31/200
# 17/30 [================>.............] - ETA: 0s - loss: 0.1154 - accuracy: 0.9706
# Epoch 31: val_accuracy did not improve from 0.95652
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1002 - accuracy: 0.9706 - val_loss: 0.1021 - val_accuracy: 0.9565
# Epoch 32/200
# 19/30 [==================>...........] - ETA: 0s - loss: 0.1247 - accuracy: 0.9408
# Epoch 32: val_accuracy did not improve from 0.95652
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1322 - accuracy: 0.9496 - val_loss: 0.1090 - val_accuracy: 0.9565
# Epoch 33/200
# 25/30 [========================>.....] - ETA: 0s - loss: 0.1126 - accuracy: 0.9650
# Epoch 33: val_accuracy did not improve from 0.95652
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1160 - accuracy: 0.9580 - val_loss: 0.1022 - val_accuracy: 0.9457
# Epoch 34/200
# 21/30 [====================>.........] - ETA: 0s - loss: 0.1074 - accuracy: 0.9524
# Epoch 34: val_accuracy improved from 0.95652 to 0.96739, saving model to weights.best.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1002 - accuracy: 0.9580 - val_loss: 0.0988 - val_accuracy: 0.9674
# Epoch 35/200
# 17/30 [================>.............] - ETA: 0s - loss: 0.0913 - accuracy: 0.9853
# Epoch 35: val_accuracy did not improve from 0.96739
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1022 - accuracy: 0.9706 - val_loss: 0.0954 - val_accuracy: 0.9674
# Epoch 36/200
# 25/30 [========================>.....] - ETA: 0s - loss: 0.1043 - accuracy: 0.9650
# Epoch 36: val_accuracy did not improve from 0.96739
# 30/30 [==============================] - 0s 4ms/step - loss: 0.1114 - accuracy: 0.9622 - val_loss: 0.0951 - val_accuracy: 0.9457
# Epoch 37/200
# 18/30 [=================>............] - ETA: 0s - loss: 0.1046 - accuracy: 0.9722
# Epoch 37: val_accuracy did not improve from 0.96739
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1103 - accuracy: 0.9664 - val_loss: 0.0905 - val_accuracy: 0.9674
# Epoch 38/200
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0600 - accuracy: 0.9868
# Epoch 38: val_accuracy did not improve from 0.96739
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0733 - accuracy: 0.9706 - val_loss: 0.0882 - val_accuracy: 0.9674
# Epoch 39/200
# 22/30 [=====================>........] - ETA: 0s - loss: 0.0938 - accuracy: 0.9659
# Epoch 39: val_accuracy improved from 0.96739 to 0.97826, saving model to weights.best.hdf5
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0889 - accuracy: 0.9706 - val_loss: 0.0934 - val_accuracy: 0.9783
# Epoch 40/200
# 22/30 [=====================>........] - ETA: 0s - loss: 0.1125 - accuracy: 0.9545
# Epoch 40: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0962 - accuracy: 0.9622 - val_loss: 0.0865 - val_accuracy: 0.9674
# Epoch 41/200
# 20/30 [===================>..........] - ETA: 0s - loss: 0.1222 - accuracy: 0.9500
# Epoch 41: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0990 - accuracy: 0.9622 - val_loss: 0.0938 - val_accuracy: 0.9674
# Epoch 42/200
# 19/30 [==================>...........] - ETA: 0s - loss: 0.0890 - accuracy: 0.9474
# Epoch 42: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0899 - accuracy: 0.9496 - val_loss: 0.0807 - val_accuracy: 0.9674
# Epoch 43/200
# 21/30 [====================>.........] - ETA: 0s - loss: 0.0615 - accuracy: 0.9762
# Epoch 43: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0776 - accuracy: 0.9664 - val_loss: 0.0726 - val_accuracy: 0.9674
# Epoch 44/200
# 23/30 [======================>.......] - ETA: 0s - loss: 0.0987 - accuracy: 0.9728
# Epoch 44: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1062 - accuracy: 0.9706 - val_loss: 0.0764 - val_accuracy: 0.9565
# Epoch 45/200
# 27/30 [==========================>...] - ETA: 0s - loss: 0.1015 - accuracy: 0.9630
# Epoch 45: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0981 - accuracy: 0.9622 - val_loss: 0.0789 - val_accuracy: 0.9783
# Epoch 46/200
# 26/30 [=========================>....] - ETA: 0s - loss: 0.1145 - accuracy: 0.9615
# Epoch 46: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1074 - accuracy: 0.9664 - val_loss: 0.0729 - val_accuracy: 0.9674
# Epoch 47/200
# 25/30 [========================>.....] - ETA: 0s - loss: 0.0890 - accuracy: 0.9550
# Epoch 47: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0839 - accuracy: 0.9622 - val_loss: 0.0740 - val_accuracy: 0.9783
# Epoch 48/200
# 25/30 [========================>.....] - ETA: 0s - loss: 0.0736 - accuracy: 0.9700
# Epoch 48: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0690 - accuracy: 0.9706 - val_loss: 0.0741 - val_accuracy: 0.9783
# Epoch 49/200
# 28/30 [===========================>..] - ETA: 0s - loss: 0.0653 - accuracy: 0.9821
# Epoch 49: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0702 - accuracy: 0.9790 - val_loss: 0.0741 - val_accuracy: 0.9674
# Epoch 50/200
# 29/30 [============================>.] - ETA: 0s - loss: 0.0745 - accuracy: 0.9741
# Epoch 50: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0727 - accuracy: 0.9748 - val_loss: 0.0688 - val_accuracy: 0.9783
# Epoch 51/200
# 26/30 [=========================>....] - ETA: 0s - loss: 0.0704 - accuracy: 0.9760
# Epoch 51: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0711 - accuracy: 0.9748 - val_loss: 0.0677 - val_accuracy: 0.9674
# Epoch 52/200
# 22/30 [=====================>........] - ETA: 0s - loss: 0.0786 - accuracy: 0.9716
# Epoch 52: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0866 - accuracy: 0.9664 - val_loss: 0.0792 - val_accuracy: 0.9674
# Epoch 53/200
# 24/30 [=======================>......] - ETA: 0s - loss: 0.0474 - accuracy: 0.9896
# Epoch 53: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0548 - accuracy: 0.9790 - val_loss: 0.0738 - val_accuracy: 0.9674
# Epoch 54/200
# 29/30 [============================>.] - ETA: 0s - loss: 0.0908 - accuracy: 0.9612
# Epoch 54: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0887 - accuracy: 0.9622 - val_loss: 0.0966 - val_accuracy: 0.9674
# Epoch 55/200
# 25/30 [========================>.....] - ETA: 0s - loss: 0.0660 - accuracy: 0.9800
# Epoch 55: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0778 - accuracy: 0.9706 - val_loss: 0.0844 - val_accuracy: 0.9565
# Epoch 56/200
# 25/30 [========================>.....] - ETA: 0s - loss: 0.0932 - accuracy: 0.9700
# Epoch 56: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 11ms/step - loss: 0.1005 - accuracy: 0.9706 - val_loss: 0.0835 - val_accuracy: 0.9674
# Epoch 57/200
# 26/30 [=========================>....] - ETA: 0s - loss: 0.0600 - accuracy: 0.9712
# Epoch 57: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0751 - accuracy: 0.9706 - val_loss: 0.0629 - val_accuracy: 0.9783
# Epoch 58/200
# 25/30 [========================>.....] - ETA: 0s - loss: 0.0887 - accuracy: 0.9550
# Epoch 58: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0820 - accuracy: 0.9622 - val_loss: 0.0734 - val_accuracy: 0.9674
# Epoch 59/200
# 26/30 [=========================>....] - ETA: 0s - loss: 0.0606 - accuracy: 0.9808
# Epoch 59: val_accuracy did not improve from 0.97826
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0606 - accuracy: 0.9790 - val_loss: 0.0671 - val_accuracy: 0.9674

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# Evaluate the model using the TEST dataset
loss, accuracy = model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 11ms/step - loss: 0.1274 - accuracy: 0.9796

# %%
# confusion matrix for sigmoid
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """Plots the confusion matrix."""
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# Classify pose in the TEST dataset using the trained model
y_pred = model.predict(X_test)

# Convert the prediction probabilities to class labels (0 or 1)
y_pred_label = (y_pred >= 0.5).astype(int)

y_true_label = y_test  

# Plot the confusion matrix
cm = confusion_matrix(y_true_label, y_pred_label)
plot_confusion_matrix(cm,
                      classes=['down', 'up'],
                      title='Confusion Matrix of Pose Classification Model')

# Print the classification report
print('\nClassification Report:\n', classification_report(y_true_label,
                                                          y_pred_label,
                                                          target_names=['class 0', 'class 1']))
# Out:
# 2/2 [==============================] - 0s 6ms/step
# Confusion matrix, without normalization
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      class 0       0.96      1.00      0.98        22
#      class 1       1.00      0.96      0.98        27
#
#     accuracy                           0.98        49
#    macro avg       0.98      0.98      0.98        49
# weighted avg       0.98      0.98      0.98        49

# %% [markdown]
# **Save Model**

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

print('Model size: %dKB' % (len(tflite_model) / 1024))

with open('triceps_sigmoid.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# Model size: 25KB
