# %%
import csv
import cv2
import numpy as np
import pandas as pd
import os
import sys
import tempfile
import tqdm
import itertools
from matplotlib import pyplot as plt
from math import atan2, degrees, sqrt
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Path of the folder that contains the entire dataset
database_path = '/content/drive/MyDrive/capstone/push up/dataset'

# Path of the folder to store the split dataset
train_dir = database_path + '/train'
val_dir = database_path + '/val'
test_dir = database_path + '/test'

# Path for each class push up position
up_position_path = database_path + '/push_up_up'
down_position_path = database_path + '/push_up_down'

# %%
def split_dataset(position_path, train_dir, val_dir):
  # Split the dataset into train and val subsets
  train_images, val_images = train_test_split(os.listdir(position_path), test_size=0.2)

  # Move the images to the train, validation, and test folders
  def move_images(path_dir, images):
      for image in images:
          os.rename(os.path.join(position_path, image), os.path.join(path_dir, image))

  move_images(train_dir, train_images)
  move_images(val_dir, val_images)
  # move_images(test_dir, test_images)

# Run the split_dataset function to split the dataset of each push up position.
split_dataset(up_position_path, train_dir+'/up', val_dir+'/up')
split_dataset(down_position_path, train_dir+'/down', val_dir+'/down')

# %%
# Download model from TF Hub and check out inference code from GitHub
# !wget -q -O movenet_thunder.tflite https://tfhub.dev/google/lite-model/movenet/singlepose/thunder/tflite/float16/4?lite-format=tflite
# !git clone https://github.com/tensorflow/examples.git
pose_sample_rpi_path = os.path.join(os.getcwd(), 'examples/lite/examples/pose_estimation/raspberry_pi')
sys.path.append(pose_sample_rpi_path)

# Load MoveNet Thunder model
import utils
from data import BodyPart
from ml import Movenet
movenet = Movenet('movenet_thunder')

# Define function to run pose estimation using MoveNet Thunder.
# Apply MoveNet's cropping algorithm and run inference multiple times on the input image to improve pose estimation accuracy.
def detect(input_tensor, inference_count=3):
  image_height, image_width, channel = input_tensor.shape

  # Detect pose using the full input image
  movenet.detect(input_tensor.numpy(), reset_crop_region=True)

  # Repeatedly using previous detection result to identify the region of interest and only croping that region to improve detection accuracy
  for _ in range(inference_count - 1):
    person = movenet.detect(input_tensor.numpy(),
                            reset_crop_region=False)

  return person
# Out:
# Cloning into 'examples'...
# remote: Enumerating objects: 23745, done.
# remote: Total 23745 (delta 0), reused 0 (delta 0), pack-reused 23745
# Receiving objects: 100% (23745/23745), 44.08 MiB | 10.27 MiB/s, done.
# Resolving deltas: 100% (12942/12942), done.
# Updating files: 100% (2850/2850), done.

# %%
def draw_prediction_on_image(image, person, crop_region=None, close_figure=True, keep_input_size=False):
  # Draw the detection result on top of the image.
  image_np = utils.visualize(image, [person])

  # Plot the image with detection results.
  height, width, channel = image.shape
  aspect_ratio = float(width) / height
  fig, ax = plt.subplots(figsize=(12 * aspect_ratio, 12))
  im = ax.imshow(image_np)

  if close_figure:
    plt.close(fig)

  if not keep_input_size:
    image_np = utils.keep_aspect_ratio_resizer(image_np, (512, 512))

  return image_np

# %%
class MoveNetPreprocessor(object):
  def __init__(self,
               images_in_folder,
               images_out_folder,
               csvs_out_path):
    self._images_in_folder = images_in_folder
    self._images_out_folder = images_out_folder
    self._csvs_out_path = csvs_out_path
    self._messages = []

    # Create a temp dir to store the pose CSVs per class
    self._csvs_out_folder_per_class = tempfile.mkdtemp()

    # Get list of pose classes and print image statistics
    self._pose_class_names = sorted(
        [n for n in os.listdir(self._images_in_folder) if not n.startswith('.')]
        )

  def process(self, per_pose_class_limit=None, detection_threshold=0.1):
    # Loop through the classes and preprocess its images
    for pose_class_name in self._pose_class_names:
      print('Preprocessing', pose_class_name, file=sys.stderr)

      # Paths for the pose class.
      images_in_folder = os.path.join(self._images_in_folder, pose_class_name)
      images_out_folder = os.path.join(self._images_out_folder, pose_class_name)
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  pose_class_name + '.csv')
      if not os.path.exists(images_out_folder):
        os.makedirs(images_out_folder)

      # Detect landmarks in each image and write it to a CSV file
      with open(csv_out_path, 'w') as csv_out_file:
        csv_out_writer = csv.writer(csv_out_file,
                                    delimiter=',',
                                    quoting=csv.QUOTE_MINIMAL)
        # Get list of images
        image_names = sorted(
            [n for n in os.listdir(images_in_folder) if not n.startswith('.')])
        if per_pose_class_limit is not None:
          image_names = image_names[:per_pose_class_limit]

        valid_image_count = 0

        # Detect pose landmarks from each image
        for image_name in tqdm.tqdm(image_names):
          image_path = os.path.join(images_in_folder, image_name)

          try:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image)
          except:
            self._messages.append('Skipped ' + image_path + '. Invalid image.')
            continue
          else:
            image = tf.io.read_file(image_path)
            image = tf.io.decode_jpeg(image)
            image_height, image_width, channel = image.shape

          # Skip images that isn't RGB because Movenet requires RGB images
          if channel != 3:
            self._messages.append('Skipped ' + image_path +
                                  '. Image isn\'t in RGB format.')
            continue
          person = detect(image)

          # Save landmarks if all landmarks were detected
          min_landmark_score = min(
              [keypoint.score for keypoint in person.keypoints])
          should_keep_image = min_landmark_score >= detection_threshold
          if not should_keep_image:
            self._messages.append('Skipped ' + image_path +
                                  '. No pose was confidentlly detected.')
            continue

          valid_image_count += 1

          # Draw the prediction result on top of the image for debugging later
          output_overlay = draw_prediction_on_image(
              image.numpy().astype(np.uint8), person,
              close_figure=True, keep_input_size=True)

          # Write detection result into an image file
          output_frame = cv2.cvtColor(output_overlay, cv2.COLOR_RGB2BGR)
          cv2.imwrite(os.path.join(images_out_folder, image_name), output_frame)

          # Get landmarks and scale it to the same size as the input image
          pose_landmarks = np.array(
              [[keypoint.coordinate.x, keypoint.coordinate.y, keypoint.score]
                for keypoint in person.keypoints],
              dtype=np.float32)

          # Write the landmark coordinates to its per-class CSV file
          coordinates = pose_landmarks.flatten().astype(str).tolist()
          csv_out_writer.writerow([image_name] + coordinates)

        if not valid_image_count:
          raise RuntimeError(
              'No valid images found for the "{}" class.'
              .format(pose_class_name))

    # Print the error message collected during preprocessing.
    print('\n'.join(self._messages))

    # Combine all per-class CSVs into a single output file
    all_landmarks_df = self._all_landmarks_as_dataframe()
    all_landmarks_df.to_csv(self._csvs_out_path, index=False)

  def class_names(self):
    """List of classes found in the training dataset."""
    return self._pose_class_names

  def _all_landmarks_as_dataframe(self):
    """Merge all per-class CSVs into a single dataframe."""
    total_df = None
    for class_index, class_name in enumerate(self._pose_class_names):
      csv_out_path = os.path.join(self._csvs_out_folder_per_class,
                                  class_name + '.csv')
      per_class_df = pd.read_csv(csv_out_path, header=None)

      # Add the labels
      per_class_df['class_no'] = [class_index]*len(per_class_df)
      per_class_df['class_name'] = [class_name]*len(per_class_df)

      # Append the folder name to the filename column (first column)
      per_class_df[per_class_df.columns[0]] = (os.path.join(class_name, '')
        + per_class_df[per_class_df.columns[0]].astype(str))

      if total_df is None:
        # For the first class, assign its data to the total dataframe
        total_df = per_class_df
      else:
        # Concatenate each class's data into the total dataframe
        total_df = pd.concat([total_df, per_class_df], axis=0)

    list_name = [[bodypart.name + '_x', bodypart.name + '_y',
                  bodypart.name + '_score'] for bodypart in BodyPart]
    header_name = []
    for columns_name in list_name:
      header_name += columns_name
    header_name = ['file_name'] + header_name
    header_map = {total_df.columns[i]: header_name[i]
                  for i in range(len(header_name))}

    total_df.rename(header_map, axis=1, inplace=True)

    return total_df

# %%
def preprocess_data(path_dir, out_dir):
    images_in_folder = path_dir
    images_out_folder = out_dir
    csvs_out_path = path_dir+'/_landmark.csv'

    preprocessor = MoveNetPreprocessor(
        images_in_folder=images_in_folder,
        images_out_folder=images_out_folder,
        csvs_out_path=csvs_out_path,)
    preprocessor.process()

preprocess_data(train_dir, database_path+'/output_train')
preprocess_data(val_dir, database_path+'/output_val')
preprocess_data(test_dir, database_path+'/output_test')
# Out:
# Preprocessing down
# 100%|██████████| 199/199 [11:23<00:00,  3.44s/it]
# Preprocessing up
# 100%|██████████| 260/260 [14:55<00:00,  3.44s/it]
# Preprocessing down
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/ice_screenshot_20211023-014206_png.rf.b1299e0148695f306785ff37c21454b1.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/ice_screenshot_20211023-015500_png.rf.affcc35860e48f5c6bec41faf9585f88.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/ice_screenshot_20211023-023126_png.rf.55e046951cccd26b4f5b1d8ad06cfecd.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/ice_screenshot_20211023-023840_png.rf.487692ebd67561fb331a342e210c77d6.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_1700051.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_1700061.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_2000021.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_2000081.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_2500051.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5100101.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5200011.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5200331.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5400011.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5400161.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5400361.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5400401.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5400471.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5400501.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5400541.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5400651.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5400691.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5500021.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5600021.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5600091.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5600141.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5600151.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5600211.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5600261.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5600271.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5600321.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5600371.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5600381.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/push up_5600551.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/pushup%20(928)_jpg.rf.ebdea0fb792544c1a35bf0096e46ccee.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/pushup%20(941)_jpg.rf.697d0b52243594e3e8b1cddae7b064d3.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/pushup%20(947)_jpg.rf.c03fca86fd79bcb07d25d52e81fe89e6.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/pushup%20(969)_jpg.rf.60d5bbe06ced65851b28b7876cefcfd0.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/pushup%20(977)_jpg.rf.4533ad12e276bff7766d053aa2560661.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/pushup%20(979)_jpg.rf.a0cee9cbb61ffcd722cf870b56c6d889.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/pushup%20(983)_jpg.rf.f7460b6250edf8a0de56d6e137d7d299.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/pushup%20(994)_jpg.rf.f748ec137a1104405ed4b7146c410e27.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/test-20-144-_jpeg.rf.b9dee8c4c489e95c0e4fe2d33fca05b2.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/test-20-169-_jpg.rf.bac4f94f9d74216a631e5d8924db82af.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/down/test-20-176-_jpeg.rf.54d4874cc772a12151521641dbd8e2bf.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/ice_screenshot_20211023-013959_png.rf.2273a997a187bea67c8e061faa5d3703.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/ice_screenshot_20211023-015439_png.rf.04bb854e6063977530c714f2acf68c13.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/push up_1000001.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/push up_1000051.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/push up_1000061.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/push up_3700041.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/push up_3700141.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/push up_3900001.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/push up_3900011.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/push up_3900071.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/push up_3900081.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/push up_3900091.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/push up_5300361.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/push up_g14.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/pushup%20(984)_jpg.rf.9b0decabb40f84eff12f8552072426f4.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/test-20-29-_jpeg.rf.a49d14f38ceb12032fcc90a87788f973.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/train/up/test-20-4-_jpeg.rf.ee8c76ee4cebbf85948ecab13a8d250a.jpg. No pose was confidentlly detected.
# 100%|██████████| 50/50 [03:14<00:00,  3.90s/it]
# Preprocessing up
# 100%|██████████| 65/65 [04:12<00:00,  3.88s/it]
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/down/ice_screenshot_20211023-015150_png.rf.f14e95626e4a9ab25f99d0144bb52af1.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/down/push up_2000091.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/down/push up_2500031.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/down/push up_5400031.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/down/push up_5400131.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/down/push up_5400231.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/down/push up_5400611.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/down/push up_5600081.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/down/push up_5600201.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/down/push up_5600431.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/down/push up_5600481.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/down/push up_5600491.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/down/pushup%20(985)_jpg.rf.6630a2aed341711ac5828b9ff5434662.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/down/test-20-183-_jpg.rf.d684eced2b49aa755c5dab4365dd610f.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/down/test-20-28-_jpeg.rf.f262784608543920316c4bf385652fe6.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/down/test-20-3-_jpeg.rf.af08de49dfc2a4720967b412d5471826.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/up/push up_1000101.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/up/push up_1700081.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/up/pushup%20(914)_jpg.rf.1a0f675dc9f57cf73afcfde6bf6a3660.jpg. No pose was confidentlly detected.
# Skipped /content/drive/MyDrive/capstone/push up/push_up/val/up/pushup%20(955)_jpg.rf.1deef5539058ee815b420cc0016d2fa2.jpg. No pose was confidentlly detected.

# %%
# Path file _landmark.csv tiap dataset
TRAINING_FILE = train_dir + '/_landmark.csv'
VALIDATION_FILE = val_dir + '/_landmark.csv'
TESTING_FILE = test_dir + '/_landmark.csv'

# %%
def load_data(file_path):
    dataframe = pd.read_csv(file_path)
    df_to_process = dataframe.copy()

    # Drop the file_name columns as you don't need it during training.
    df_to_process.drop(columns=['file_name'], inplace=True)

    # Extract the list of class names
    classes = df_to_process.pop('class_name').unique()

    # Extract the labels
    y = df_to_process.pop('class_no')

    # Convert the input features and labels into the correct format for training.
    X = df_to_process.astype('float64').values
    # y = keras.utils.to_categorical(y)

    return X, y, classes, dataframe

# Load train, validation, and test data
try:
    X_train, y_train, class_names, _ = load_data(TRAINING_FILE)
    X_val, y_val, class_names, _ = load_data(VALIDATION_FILE)
    X_test, y_test, class_names, _ = load_data(TESTING_FILE)
except Exception as e:
    print(f"Error loading data: {e}")

print(f"Length X_train: {len(X_train)}, X_train Shape: {X_train.shape}, Length y_train: {len(y_train)}, y_train Shape: {y_train.shape}")
print(f"Length X_val: {len(X_val)}, X_val Shape: {X_val.shape}, Length y_val: {len(y_val)}, y_val Shape: {y_val.shape}")
print(f"Length X_test: {len(X_test)}, X_test Shape: {X_test.shape}, Length y_test: {len(y_test)}, y_test Shape: {y_test.shape}")
# Out:
# Length X_train: 398, X_train Shape: (398, 51), Length y_train: 398, y_train Shape: (398,)
# Length X_val: 95, X_val Shape: (95, 51), Length y_val: 95, y_val Shape: (95,)
# Length X_test: 85, X_test Shape: (85, 51), Length y_test: 85, y_test Shape: (85,)

# %%
def get_center_point(landmarks, left_bodypart, right_bodypart):
  """Calculates the center point of the two given landmarks."""

  left = tf.gather(landmarks, left_bodypart.value, axis=1)
  right = tf.gather(landmarks, right_bodypart.value, axis=1)
  center = left * 0.5 + right * 0.5
  return center


def get_pose_size(landmarks, torso_size_multiplier=2.5):
  """Calculates pose size.

  It is the maximum of two values:
    * Torso size multiplied by `torso_size_multiplier`
    * Maximum distance from pose center to any pose landmark
  """
  # Hips center
  hips_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                 BodyPart.RIGHT_HIP)

  # Shoulders center
  shoulders_center = get_center_point(landmarks, BodyPart.LEFT_SHOULDER,
                                      BodyPart.RIGHT_SHOULDER)

  # Torso size as the minimum body size
  torso_size = tf.linalg.norm(shoulders_center - hips_center)

  # Pose center
  pose_center_new = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                     BodyPart.RIGHT_HIP)
  pose_center_new = tf.expand_dims(pose_center_new, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to
  # perform substraction
  pose_center_new = tf.broadcast_to(pose_center_new,
                                    [tf.size(landmarks) // (17*2), 17, 2])

  # Dist to pose center
  d = tf.gather(landmarks - pose_center_new, 0, axis=0,
                name="dist_to_pose_center")
  # Max dist to pose center
  max_dist = tf.reduce_max(tf.linalg.norm(d, axis=0))

  # Normalize scale
  pose_size = tf.maximum(torso_size * torso_size_multiplier, max_dist)

  return pose_size


def normalize_pose_landmarks(landmarks):
  """Normalizes the landmarks translation by moving the pose center to (0,0) and
  scaling it to a constant pose size.
  """
  # Move landmarks so that the pose center becomes (0,0)
  pose_center = get_center_point(landmarks, BodyPart.LEFT_HIP,
                                 BodyPart.RIGHT_HIP)
  pose_center = tf.expand_dims(pose_center, axis=1)
  # Broadcast the pose center to the same size as the landmark vector to perform
  # substraction
  pose_center = tf.broadcast_to(pose_center,
                                [tf.size(landmarks) // (17*2), 17, 2])
  landmarks = landmarks - pose_center

  # Scale the landmarks to a constant pose size
  pose_size = get_pose_size(landmarks)
  landmarks /= pose_size

  return landmarks


def landmarks_to_embedding(landmarks_and_scores):
  """Converts the input landmarks into a pose embedding."""
  # Reshape the flat input into a matrix with shape=(17, 3)
  reshaped_inputs = keras.layers.Reshape((17, 3))(landmarks_and_scores)

  # Normalize landmarks 2D
  landmarks = normalize_pose_landmarks(reshaped_inputs[:, :, :2])

  # Flatten the normalized landmark coordinates into a vector
  embedding = keras.layers.Flatten()(landmarks)

  return embedding

# %%
# Define the model

model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(51,)),
    tf.keras.layers.Lambda(landmarks_to_embedding),
    tf.keras.layers.Dense(128, activation=tf.nn.relu6),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(64, activation=tf.nn.relu6),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation="sigmoid")
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lambda (Lambda)             (None, 34)                0
#
#  dense (Dense)               (None, 128)               4480
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 12801 (50.00 KB)
# Trainable params: 12801 (50.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Add a checkpoint callback to store the checkpoint that has the highest
# validation accuracy.
checkpoint_path = "weights.best.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(checkpoint_path,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True,
                             mode='max')
earlystopping = keras.callbacks.EarlyStopping(monitor='val_accuracy',
                                              patience=20)

# Start training
history = model.fit(X_train, y_train,
                    epochs=200,
                    batch_size=16,
                    validation_data=(X_val, y_val),
                    callbacks=[checkpoint, earlystopping])
# Out:
# Epoch 1/200
# 22/25 [=========================>....] - ETA: 0s - loss: 0.6743 - accuracy: 0.6619
# Epoch 1: val_accuracy improved from -inf to 0.65263, saving model to weights.best.hdf5
# 25/25 [==============================] - 2s 27ms/step - loss: 0.6751 - accuracy: 0.6558 - val_loss: 0.6359 - val_accuracy: 0.6526
# Epoch 2/200
#  1/25 [>.............................] - ETA: 0s - loss: 0.6394 - accuracy: 0.7500
# Epoch 2: val_accuracy improved from 0.65263 to 0.72632, saving model to weights.best.hdf5
# 25/25 [==============================] - 0s 5ms/step - loss: 0.6203 - accuracy: 0.7362 - val_loss: 0.5516 - val_accuracy: 0.7263
# Epoch 3/200
#  1/25 [>.............................] - ETA: 0s - loss: 0.5891 - accuracy: 0.7500
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 21/25 [========================>.....] - ETA: 0s - loss: 0.5434 - accuracy: 0.7827
# Epoch 3: val_accuracy improved from 0.72632 to 0.84211, saving model to weights.best.hdf5
# 25/25 [==============================] - 0s 5ms/step - loss: 0.5352 - accuracy: 0.7965 - val_loss: 0.4204 - val_accuracy: 0.8421
# Epoch 4/200
# 23/25 [==========================>...] - ETA: 0s - loss: 0.4324 - accuracy: 0.8587
# Epoch 4: val_accuracy improved from 0.84211 to 0.89474, saving model to weights.best.hdf5
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4226 - accuracy: 0.8693 - val_loss: 0.2769 - val_accuracy: 0.8947
# Epoch 5/200
# 15/25 [=================>............] - ETA: 0s - loss: 0.3016 - accuracy: 0.9292
# Epoch 5: val_accuracy improved from 0.89474 to 0.97895, saving model to weights.best.hdf5
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2869 - accuracy: 0.9246 - val_loss: 0.1686 - val_accuracy: 0.9789
# Epoch 6/200
#  1/25 [>.............................] - ETA: 0s - loss: 0.2318 - accuracy: 0.9375
# Epoch 6: val_accuracy improved from 0.97895 to 0.98947, saving model to weights.best.hdf5
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2077 - accuracy: 0.9573 - val_loss: 0.1095 - val_accuracy: 0.9895
# Epoch 7/200
#  1/25 [>.............................] - ETA: 0s - loss: 0.2934 - accuracy: 0.9375
# Epoch 7: val_accuracy did not improve from 0.98947
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1538 - accuracy: 0.9698 - val_loss: 0.0784 - val_accuracy: 0.9895
# Epoch 8/200
#  1/25 [>.............................] - ETA: 0s - loss: 0.1265 - accuracy: 1.0000
# Epoch 8: val_accuracy did not improve from 0.98947
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1287 - accuracy: 0.9824 - val_loss: 0.0604 - val_accuracy: 0.9895
# Epoch 9/200
# 23/25 [==========================>...] - ETA: 0s - loss: 0.1055 - accuracy: 0.9783
# Epoch 9: val_accuracy did not improve from 0.98947
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1038 - accuracy: 0.9799 - val_loss: 0.0497 - val_accuracy: 0.9895
# Epoch 10/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1014 - accuracy: 0.9749
# Epoch 10: val_accuracy did not improve from 0.98947
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1014 - accuracy: 0.9749 - val_loss: 0.0388 - val_accuracy: 0.9895
# Epoch 11/200
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0774 - accuracy: 0.9864
# Epoch 11: val_accuracy did not improve from 0.98947
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0756 - accuracy: 0.9874 - val_loss: 0.0332 - val_accuracy: 0.9895
# Epoch 12/200
# 15/25 [=================>............] - ETA: 0s - loss: 0.0743 - accuracy: 0.9875
# Epoch 12: val_accuracy did not improve from 0.98947
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0750 - accuracy: 0.9799 - val_loss: 0.0275 - val_accuracy: 0.9895
# Epoch 13/200
# 20/25 [=======================>......] - ETA: 0s - loss: 0.0828 - accuracy: 0.9781
# Epoch 13: val_accuracy did not improve from 0.98947
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0751 - accuracy: 0.9824 - val_loss: 0.0256 - val_accuracy: 0.9895
# Epoch 14/200
# 16/25 [==================>...........] - ETA: 0s - loss: 0.0544 - accuracy: 0.9844
# Epoch 14: val_accuracy improved from 0.98947 to 1.00000, saving model to weights.best.hdf5
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0631 - accuracy: 0.9799 - val_loss: 0.0218 - val_accuracy: 1.0000
# Epoch 15/200
# 13/25 [==============>...............] - ETA: 0s - loss: 0.0603 - accuracy: 0.9760
# Epoch 15: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0624 - accuracy: 0.9799 - val_loss: 0.0187 - val_accuracy: 1.0000
# Epoch 16/200
# 19/25 [=====================>........] - ETA: 0s - loss: 0.0530 - accuracy: 0.9868
# Epoch 16: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0554 - accuracy: 0.9874 - val_loss: 0.0153 - val_accuracy: 1.0000
# Epoch 17/200
#  1/25 [>.............................] - ETA: 0s - loss: 0.0202 - accuracy: 1.0000
# Epoch 17: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 3ms/step - loss: 0.0474 - accuracy: 0.9874 - val_loss: 0.0133 - val_accuracy: 1.0000
# Epoch 18/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0449 - accuracy: 0.9925
# Epoch 18: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0449 - accuracy: 0.9925 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 19/200
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0511 - accuracy: 0.9851
# Epoch 19: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0473 - accuracy: 0.9874 - val_loss: 0.0098 - val_accuracy: 1.0000
# Epoch 20/200
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0432 - accuracy: 0.9864
# Epoch 20: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0408 - accuracy: 0.9874 - val_loss: 0.0096 - val_accuracy: 1.0000
# Epoch 21/200
# 17/25 [===================>..........] - ETA: 0s - loss: 0.0467 - accuracy: 0.9890
# Epoch 21: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0404 - accuracy: 0.9925 - val_loss: 0.0104 - val_accuracy: 1.0000
# Epoch 22/200
# 20/25 [=======================>......] - ETA: 0s - loss: 0.0297 - accuracy: 0.9937
# Epoch 22: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0334 - accuracy: 0.9925 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 23/200
#  1/25 [>.............................] - ETA: 0s - loss: 0.0387 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0368 - accuracy: 0.9899 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 24/200
# 22/25 [=========================>....] - ETA: 0s - loss: 0.0405 - accuracy: 0.9886
# Epoch 24: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0427 - accuracy: 0.9874 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 25/200
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0286 - accuracy: 0.9946
# Epoch 25: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0308 - accuracy: 0.9925 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 26/200
# 19/25 [=====================>........] - ETA: 0s - loss: 0.0289 - accuracy: 0.9901
# Epoch 26: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0309 - accuracy: 0.9899 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 27/200
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0214 - accuracy: 0.9973
# Epoch 27: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0217 - accuracy: 0.9975 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 28/200
# 16/25 [==================>...........] - ETA: 0s - loss: 0.0255 - accuracy: 0.9922
# Epoch 28: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0227 - accuracy: 0.9950 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 29/200
# 14/25 [===============>..............] - ETA: 0s - loss: 0.0115 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 7ms/step - loss: 0.0221 - accuracy: 0.9950 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 30/200
# 16/25 [==================>...........] - ETA: 0s - loss: 0.0233 - accuracy: 0.9961
# Epoch 30: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0244 - accuracy: 0.9975 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 31/200
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0430 - accuracy: 0.9891
# Epoch 31: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0441 - accuracy: 0.9874 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 32/200
# 19/25 [=====================>........] - ETA: 0s - loss: 0.0480 - accuracy: 0.9803
# Epoch 32: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0396 - accuracy: 0.9849 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 33/200
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0230 - accuracy: 0.9946
# Epoch 33: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0218 - accuracy: 0.9950 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 34/200
# 21/25 [========================>.....] - ETA: 0s - loss: 0.0230 - accuracy: 0.9970
# Epoch 34: val_accuracy did not improve from 1.00000
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0215 - accuracy: 0.9975 - val_loss: 0.0049 - val_accuracy: 1.0000

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# Evaluate the model using the TEST dataset
loss, accuracy = model.evaluate(X_test, y_test)
# Out:
# 3/3 [==============================] - 0s 5ms/step - loss: 0.0491 - accuracy: 0.9882

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """Plots the confusion matrix."""
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=55)
    plt.yticks(tick_marks, classes)
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# Classify pose in the TEST dataset using the trained model
y_pred = model.predict(X_test)

# Convert the prediction probabilities to class labels (0 or 1)
y_pred_label = (y_pred >= 0.5).astype(int)

y_true_label = y_test 

# Plot the confusion matrix
cm = confusion_matrix(y_true_label, y_pred_label)
plot_confusion_matrix(cm,
                      classes=['down', 'up'], 
                      title='Confusion Matrix of Pose Classification Model')

# Print the classification report
print('\nClassification Report:\n', classification_report(y_true_label,
                                                          y_pred_label,
                                                          target_names=['class 0', 'class 1']))
# Out:
# 3/3 [==============================] - 0s 5ms/step
# Confusion matrix, without normalization
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      class 0       1.00      0.97      0.99        38
#      class 1       0.98      1.00      0.99        47
#
#     accuracy                           0.99        85
#    macro avg       0.99      0.99      0.99        85
# weighted avg       0.99      0.99      0.99        85

# %% [markdown]
# **Save Model**

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

print('Model size: %dKB' % (len(tflite_model) / 1024))

with open('pushup_sigmoid.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# Model size: 25KB

# %% [markdown]
# **Coba predict**
